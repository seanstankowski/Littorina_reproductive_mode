# %% [markdown]
# # Plotting topoplogy weight simulations in R

# %% [markdown]
# This notebook is only relevant to the plotting of topology weights from the coalescent simulations. These coalescent simulations were conducted in another Jupyter notebook which acts as a simulator for MS prime. The topology weighting is done using the Twisst algorythm.

# %%
### install and load the packages
install.packages("Ternary")
library("Ternary")
# Out:
# also installing the dependencies ‘httpuv’, ‘xtable’, ‘fontawesome’, ‘sourcetools’, ‘later’, ‘promises’, ‘commonmark’, ‘cachem’, ‘shiny’, ‘sp’
# The downloaded binary packages are in
# 	/var/folders/0g/lghw5vts6mx1_l8ghvqs5wrh0000gn/T//RtmpjapDbt/downloaded_packages

# %%
## example notation for drawing a 
TernaryPlot(grid.minor.lines = 0)

data_points <- list(
  A = c(100, 0, 0), 
  B = c(0, 100, 0),
  C = c(0, 0, 100),
  D = c(0.33, 0.33, 0.33))

data.frame <- (as.data.frame(data_points))

AddToTernary(points, data.frame, col="red", pch=20, cex=2)

data.frame
# Out:
#   A   B   C   D
# 1 100   0   0 0.33
# 2   0 100   0 0.33
# 3   0   0 100 0.33
# plot without title
